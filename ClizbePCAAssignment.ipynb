# %% [markdown]
# <a href="https://colab.research.google.com/github/davidclizbe/datascience/blob/master/ClizbePCAAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
from sklearn.preprocessing import StandardScaler

# %%
digits = datasets.load_digits()
X = digits.data

# %%
y = digits.target

# %%
scaled = StandardScaler()
X_scaled = scaled.fit_transform(X)
model = PCA(n_components=64)
model.fit(X_scaled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=64, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
evr = model.explained_variance_ratio_

# %%
plt.plot(evr)

# %%
csevr = np.cumsum(evr)

# %%
plt.plot(csevr)

# %%
for i in range(len(csevr)):
  if csevr[i] >= .90:
    break
print(i)
# Out:
# 30

# %%
 components = model.components_

# %%
components[0:2]
# Out:
# array([[ 1.21482737e-18, -1.82233917e-01, -2.85867997e-01,
#         -2.20369669e-01,  2.51695591e-02,  9.49725041e-03,
#          5.24764975e-02,  6.26949928e-02, -3.47072724e-02,
#         -2.45533684e-01, -2.29151737e-01,  1.07943812e-01,
#         -3.62020917e-02, -3.87115946e-02,  8.37807734e-02,
#          9.27750204e-02, -1.66993420e-02, -1.36716497e-01,
#          6.30507547e-02,  1.22879267e-01, -1.48193479e-01,
#          2.34842464e-02,  1.71199702e-01,  1.04208373e-01,
#          3.94881848e-03,  1.16389700e-01,  1.88204732e-01,
#         -6.58604010e-02, -1.43532569e-01,  1.28207049e-01,
#          1.80620749e-01,  5.27091667e-02,  0.00000000e+00,
#          2.38902514e-01,  2.35006131e-01,  5.09137360e-03,
#          1.31088082e-02,  1.59116182e-01,  1.29394163e-01,
#          0.00000000e+00,  5.55990603e-02,  1.87157069e-01,
#          1.53533710e-01,  4.68257226e-02,  1.10892715e-01,
#          1.07209473e-01, -1.79265181e-02,  2.27270999e-03,
# ...

# %%
X_new = model.transform(X_scaled)

# %%
sn.scatterplot(X_new[:,0], X_new[:,1], hue= y, palette="tab10")
